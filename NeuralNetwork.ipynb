# %%
import numpy as np
inputs = [1.0,2.0,3.0,2.5]
weights = [0.2,0.8,-0.5,1.0]
bias = 2.0
outputs = np.dot(weights, inputs) + bias
print(outputs)
# Out:
# 4.8

# %%
inputs = [1.0,2.0,3.0,2.5]
weights  = [[0.2,0.8,-0.5,1.0], [0.5,-0.91,0.26,-0.5],[-0.26,-0.27,0.17,0.87]]

biases = [2.0,3.0,0.5]
layer_outputs = np.dot(weights, inputs) + biases
print(layer_outputs)
# Out:
# [4.8   1.21  2.385]

# %%
input_size = 10  
inputs = np.random.randn(input_size)
output_size = 5  

weights = np.random.randn(output_size, input_size)
weights2 = np.random.randn(output_size, input_size)
biases = np.random.randn(output_size)
biases2 = np.random.randn(output_size)

layer_outputs = np.dot(weights, inputs) + biases
print(layer_outputs)
print(layer_outputs.shape)
# Out:
# [ 3.76247005  4.17251123 -2.82254154  5.7741228  -1.65430377]
# (5,)

# %% [markdown]
# add layers

# %%
layer1_outputs = np.dot(inputs, np.array(weights).T + bias)
layer2_outputs = np.dot(layer1_outputs, np.array(weights2).T +biases2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\cmupenzi\Desktop\AUCA\Machine Learning\NeuralNetwork.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cmupenzi/Desktop/AUCA/Machine%20Learning/NeuralNetwork.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> layer1_outputs = np.dot(inputs, np.array(weights).T + bias)
#       <a href='vscode-notebook-cell:/c%3A/Users/cmupenzi/Desktop/AUCA/Machine%20Learning/NeuralNetwork.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> layer2_outputs = np.dot(layer1_outputs, np.array(weights2).T +biases2)
#
# NameError: name 'inputs' is not defined

# %%
pip install nnfs
# Out:
# ...
#
# ...

# %%
from nnfs.datasets import spiral_data

# %%
import matplotlib.pyplot as plt
x, y = spiral_data(samples = 100, classes =3)
plt.scatter(x[:,0], x[:,1])
plt.show()

# %%
plt.scatter(x[: , 0], x[: , 1], c=y, cmap='brg')
plt.show()

# %%
import numpy as np

# Define the Layer_Dense class
class Layer_Dense:
    # Layer Initialization
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.rand(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        
    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs, weights, and biases
        self.output = np.dot(inputs, self.weights) + self.biases

# Function to create a sample dataset (you can replace this with your actual data)
def spiral_data(samples, classes):
    # Generate synthetic spiral data
    # Replace this with your data generation logic
    x = np.random.rand(samples, 2)  # Example: random 2D data
    y = np.random.randint(0, classes, size=(samples, 1))  # Example: random class labels
    return x, y

# Create dataset
x, y = spiral_data(samples=100, classes=3)

# Create dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)

# Perform a forward pass of our training data through this layer
dense1.forward(x)

# Let's see the output of the first few samples
print(dense1.output[:5])
# Out:
# [[0.000267   0.00597751 0.00312337]
#  [0.00318932 0.01029055 0.00398577]
#  [0.002126   0.0088565  0.00374575]
#  [0.0040094  0.00826648 0.00246409]
#  [0.00206712 0.00522695 0.00179662]]
